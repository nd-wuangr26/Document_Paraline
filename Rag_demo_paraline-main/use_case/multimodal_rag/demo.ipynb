# %% [markdown]
# ### Chunking ###

# %%
# !pip install -u langchain_community langchain_experimental langchain_huggingface langchain_core sentence-transformers
# Out:
# ...
#   Using cached langchain_experimental-0.3.4-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached langchain_huggingface-0.3.1-py3-none-any.whl.metadata (996 bytes)
# ...
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached aiohttp-3.12.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# ...
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_experimental.text_splitter import SemanticChunker
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(model_name="AITeamVN/Vietnamese_Embedding")
document_path = "/home/quang/Downloads/Kinh_te_cong_nghiep.pdf"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/paraline/lib/python3.10/site-packages/langchain_huggingface/embeddings/huggingface.py:69, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      68 try:
# ---> 69     import sentence_transformers  # type: ignore[import]
#      70 except ImportError as exc:
#
# ModuleNotFoundError: No module named 'sentence_transformers'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 embeddings = HuggingFaceEmbeddings(model_name="AITeamVN/Vietnamese_Embedding")
#       2 document_path = "/home/quang/Downloads/Kinh_te_cong_nghiep.pdf"
#
# ...

# %%
loader = PyPDFLoader(document_path)
documents = loader.load()

# %%
raw_texts = [doc.page_content for doc in documents]
chunker = SemanticChunker(embeddings=embeddings,
                            breakpoint_threshold_type="percentile",
                            breakpoint_threshold_amount=80)
chunks = chunker.create_documents(raw_texts)

for chunk in chunks:
    chunk.page_content = chunk.page_content.replace("\n", " ")
    chunk.page_content = " ".join(chunk.page_content.split())

# %%
print(f"Number of chunks: {len(chunks)}")
print(f"First chunk: {chunks[0].page_content}")

# %% [markdown]
# ### Vector DB ###
