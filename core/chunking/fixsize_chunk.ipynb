# %% [markdown]
# # FIX SIZE CHUNKING

# %%
# !pip install -qU langchain_text_splitters

# %%
document = "Unlike the previous methods, semantic-based splitting actually considers the content of the text. While other approaches use document or text structure as proxies for semantic meaning, this method directly analyzes the text's semantics. There are several ways to implement this, but conceptually the approach is split text when there are significant changes in text meaning. As an example, we can use a sliding window approach to generate embeddings, and compare the embeddings to find significant differences"

# %% [markdown]
# ## Su dung Langchain:

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
chunks = text_splitter.split_text(document)
for i, chunk in enumerate(chunks, 1):
    print(f"Chunk {i}: {chunk}\n")
# Out:
# Chunk 1: Unlike the previous methods, semantic-based splitting actually considers the content of the text.
#
# Chunk 2: of the text. While other approaches use document or text structure as proxies for semantic meaning,
#
# Chunk 3: semantic meaning, this method directly analyzes the text's semantics. There are several ways to
#
# Chunk 4: are several ways to implement this, but conceptually the approach is split text when there are
#
# Chunk 5: text when there are significant changes in text meaning. As an example, we can use a sliding window
#
# Chunk 6: a sliding window approach to generate embeddings, and compare the embeddings to find significant
#
# Chunk 7: to find significant differences

# %% [markdown]
# ## Khong su dung langchain

# %%
def fixed_size_chunking(text, chunk_size, overlap):
    chunks = []
    step = chunk_size - overlap
    for i in range(0, len(text), step):
        chunk = text[i:i+chunk_size]
        chunks.append(chunk)
    return chunks

chunks = fixed_size_chunking(document, chunk_size=100, overlap=20)
for i, chunk in enumerate(chunks, 1):
    print(f"Chunk {i}: {chunk}\n")
# Out:
# Chunk 1: Unlike the previous methods, semantic-based splitting actually considers the content of the text. Wh
#
# Chunk 2: tent of the text. While other approaches use document or text structure as proxies for semantic mean
#
# Chunk 3: es for semantic meaning, this method directly analyzes the text's semantics. There are several ways
#
# Chunk 4: re are several ways to implement this, but conceptually the approach is split text when there are si
#
# Chunk 5: xt when there are significant changes in text meaning. As an example, we can use a sliding window ap
#
# Chunk 6:  a sliding window approach to generate embeddings, and compare the embeddings to find significant di
#
# Chunk 7:  find significant differences
